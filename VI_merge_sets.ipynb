# %%
import os, sys
import numpy as np

from astropy.io import fits
from astropy.table import Table, join
import pandas as pd

#import desispec
# library location will change ..
#sys.path.append("/global/homes/r/rtojeiro/prospect/prospect/py")
#from prospect import utils_specviewer,plotframes
import matplotlib.pyplot as plt

# %%
VI_dir = os.environ['HOME']+'/Dropbox/DESI/DESI-VI/Mini-SV2/BGS_70502/'

# %%
#read in all VI files (previously merged)
df = pd.read_csv(VI_dir + 'vi_merged_BGS_tile70502.csv') #BGS tile 70502
vi = Table.from_pandas(df)

# %%
vi.keys()
# Out:
# ['TargetID',
#  'ExpID',
#  'Spec version',
#  'Redrock version',
#  'Redrock spectype',
#  'Redrock z',
#  'VI scanner',
#  'VI class',
#  'VI issue',
#  'VI z',
#  'VI spectype',
#  'VI comment']

# %%
#to dataframe
vi_df = vi.to_pandas()

# %%
#make new column with best redshift estimate for each VI - take VI redshift if available, else take Redrock redshift. 
#This is not strictly necessary but makes manipulation easier.
vi_df['best redshift'] = vi_df['VI z']
vi_df.loc[vi_df['best redshift']=='--', 'best_redshift'] = vi_df.loc[vi_df['best redshift']=='--', 'Redrock z']
#vi_df['best redshift'] = vi_df['best redshift'].astype(float)

# %%
vi_df
# Out:
#                TargetID  ExpID  Spec version  Redrock version  \
# 0     35185736609174572     -1             0                0
# 1     35185736613364742     -1             0                0
# 2     35185736613368369     -1             0                0
# 3     35185736613365274     -1             0                0
# 4     35185736613365164     -1             0                0
# ...                 ...    ...           ...              ...
# 1227  35185730577761118     -1             0                0
# 1228  35185730577760441     -1             0                0
# 1229  35185730573570209     -1             0                0
# 1230  35185730577760335     -1             0                0
# 1231  35185730577760717     -1             0                0
#
#      Redrock spectype  Redrock z VI scanner  VI class VI issue    VI z  \
# 0              GALAXY      0.278     acedge         4       --  0.2783
# 1              GALAXY      0.441     acedge         4       --  0.4413
# 2              GALAXY      0.263     acedge         4       --  0.2629
# 3              GALAXY      0.743     acedge         0        S      --
# 4              GALAXY      0.264     acedge         4       --  0.2635
# ...               ...        ...        ...       ...      ...     ...
# 1227           GALAXY      0.125     acedge         4       --  0.1253
# 1228           GALAXY      0.254     acedge         4       --  0.2542
# 1229           GALAXY      0.120     acedge         4       --  0.1201
# 1230           GALAXY      0.265     acedge         4       --  0.2651
# 1231           GALAXY      0.072     acedge         4       --  0.0717
#
#      VI spectype           VI comment best redshift  best_redshift
# 0         GALAXY          clear lines        0.2783            NaN
# 1         GALAXY                  LRG        0.4413            NaN
# 2         GALAXY                  LRG        0.2629            NaN
# 3             --            no signal            --          0.743
# 4         GALAXY                  LRG        0.2635            NaN
# ...          ...                  ...           ...            ...
# 1227      GALAXY  LRG with weak lines        0.1253            NaN
# 1228      GALAXY                  LRG        0.2542            NaN
# 1229      GALAXY          clear lines        0.1201            NaN
# 1230      GALAXY                  LRG        0.2651            NaN
# 1231      GALAXY          clear lines        0.0717            NaN
#
# [1232 rows x 14 columns]

# %%
#add new columns, holding the mean of the flags and the maximum difference in classification
vi_df['vi_combined_flag'] = vi_df.groupby('TargetID')['VI class'].transform('mean')
vi_df['vi_diff'] = vi_df.groupby('TargetID')['VI class'].transform(lambda x: ( x.max()-x.min()) )

# %%
#add new column, with the mean redshift from all values of 'best redshift'
vi_df['vi_combined_z'] = vi_df.groupby('TargetID')['best redshift'].transform('mean')
vi_df['dz'] = vi_df.groupby('TargetID')['best redshift'].transform(lambda x: ( (x.max() - x.min()) / (1+x.mean()) ))

# %%
#make groups of visual inspections, grouped by unique objects
vi_gp = vi_df.groupby(['TargetID'])
print('There are ' + str(len(vi_df)) + ' visual inspections of a total of ' + str(len(vi_gp)) + ' unique objects')
# Out:
# There are 1232 visual inspections of a total of 982 unique objects

# %% [markdown]
# Get a table that holds only the objects that have been inspected more than once, and for which the individual VI classifications differ by 2 or more, or delta z / (1 + z) > 0.0033 (problematic VIs)

# %%
vi_insp = vi_gp.filter(lambda x: ( ( (x['VI class'].max()-x['VI class'].min()) >= 2) 
                       | ( (x['best redshift'].max() - x['best redshift'].min()) / (1+x['best redshift'].mean()) > 0.0033 ) )
                       & (len(x) >= 2)) #x is a group by TargetID

# %% [markdown]
# Get the target IDs of the problematic objects and display in table form (later to add prospect window)

# %%
unique_targets = np.unique(vi_insp['TargetID'].tolist())
print('Targets with problematic VI: ', unique_targets)
print('Total number of conflicts to resolve: ', len(unique_targets))
# Out:
# Targets with problematic VI:  [35185712449980146 35185712454174940 35185712454175202 35185712454175731
#  35185712454176111 35185712454176649 35185712458371294 35185718485585807
#  35185718489779354 35185718489780521 35185766816546922 35185766820745119]
# Total number of conflicts to resolve:  12

# %%
for i in range(len(unique_targets)): 
    display(vi_insp[vi_insp.TargetID==unique_targets[i]])
# Out:
#               TargetID  ExpID  Spec version  Redrock version Redrock spectype  \
# 75   35185712449980146     -1             0                0           GALAXY
# 125  35185712449980146     -1             0                0           GALAXY
# 175  35185712449980146     -1             0                0           GALAXY
#
#      Redrock z VI scanner  VI class VI issue    VI z VI spectype  \
# 75        0.07        KAD         4       --      --          --
# 125       0.07     acedge         3       --  0.0704      GALAXY
# 175       0.07       rita         2       --      --          --
#
#                                      VI comment  best redshift  \
# 75                                           --         0.0700
# 125       weak lines but consistent with z=0.07         0.0704
# 175   blue jump; possible Ha; no other features         0.0700
#
#      vi_combined_flag  vi_diff  vi_combined_z        dz
# 75                3.0        2       0.070133  0.000374
# 125               3.0        2       0.070133  0.000374
# 175               3.0        2       0.070133  0.000374
#               TargetID  ExpID  Spec version  Redrock version Redrock spectype  \
# 82   35185712454174940     -1             0                0              QSO
# 132  35185712454174940     -1             0                0              QSO
# 182  35185712454174940     -1             0                0              QSO
#
#      Redrock z VI scanner  VI class VI issue    VI z VI spectype  \
# 82       1.496        KAD         1       RS  0.1475          --
# 132      1.496     acedge         0        S      --          --
# 182      1.496       rita         1       --      --          --
#
#                                             VI comment  best redshift  \
# 82   Unusual spectrum"," no strong features (possib...         0.1475
# 132                                          no signal         1.4960
# 182                                       Mayne noise?         1.4960
#
#      vi_combined_flag  vi_diff  vi_combined_z       dz
# 82           0.666667        1         1.0465  0.65893
# 132          0.666667        1         1.0465  0.65893
# 182          0.666667        1         1.0465  0.65893
#               TargetID  ExpID  Spec version  Redrock version Redrock spectype  \
# 68   35185712454175202     -1             0                0           GALAXY
# 118  35185712454175202     -1             0                0           GALAXY
# 168  35185712454175202     -1             0                0           GALAXY
#
#      Redrock z VI scanner  VI class VI issue    VI z VI spectype  \
# 68       0.975        KAD         0        R  0.4386          --
# 118      0.975     acedge         0        S      --          --
# 168      0.975       rita         0       --      --          --
#
#                                       VI comment  best redshift  \
# 68    Featureless"," no continuum"," possible Ha         0.4386
# 118                                    no signal         0.9750
# 168                                  noise only?         0.9750
#
#      vi_combined_flag  vi_diff  vi_combined_z       dz
# 68                0.0        0         0.7962  0.29863
# 118               0.0        0         0.7962  0.29863
# 168               0.0        0         0.7962  0.29863
#               TargetID  ExpID  Spec version  Redrock version Redrock spectype  \
# 84   35185712454175731     -1             0                0           GALAXY
# 134  35185712454175731     -1             0                0           GALAXY
# 184  35185712454175731     -1             0                0           GALAXY
#
#      Redrock z VI scanner  VI class VI issue    VI z VI spectype   VI comment  \
# 84       0.145        KAD         4       --      --          --           --
# 134      0.145     acedge         4       --  0.1488      GALAXY  clear lines
# 184      0.145       rita         4       --      --          --           --
#
#      best redshift  vi_combined_flag  vi_diff  vi_combined_z        dz
# 84          0.1450               4.0        0       0.146267  0.003315
# 134         0.1488               4.0        0       0.146267  0.003315
# 184         0.1450               4.0        0       0.146267  0.003315
#               TargetID  ExpID  Spec version  Redrock version Redrock spectype  \
# 56   35185712454176111     -1             0                0           GALAXY
# 106  35185712454176111     -1             0                0           GALAXY
# 156  35185712454176111     -1             0                0           GALAXY
#
#      Redrock z VI scanner  VI class VI issue    VI z VI spectype  \
# 56       0.431        KAD         4       --      --          --
# 106      0.431     acedge         2       --  0.4311      GALAXY
# 156      0.431       rita         1       --      --          --
#
#                                            VI comment  best redshift  \
# 56                                                 --         0.4310
# 106   continuum mismatch at join of blue and red arms         0.4311
# 156                   blue jump; featureless"," noisy         0.4310
#
#      vi_combined_flag  vi_diff  vi_combined_z       dz
# 56           2.333333        3       0.431033  0.00007
# 106          2.333333        3       0.431033  0.00007
# 156          2.333333        3       0.431033  0.00007
#               TargetID  ExpID  Spec version  Redrock version Redrock spectype  \
# 67   35185712454176649     -1             0                0           GALAXY
# 117  35185712454176649     -1             0                0           GALAXY
# 167  35185712454176649     -1             0                0           GALAXY
#
#      Redrock z VI scanner  VI class VI issue    VI z VI spectype  \
# 67       0.428        KAD         3       --      --          --
# 117      0.428     acedge         3       --  0.4280      GALAXY
# 167      0.428       rita         1       --      --          --
#
#                                             VI comment  best redshift  \
# 67                                                  --          0.428
# 117                             fitting double lines??          0.428
# 167   wrong z. tentative fit to 4000A break. very w...          0.428
#
#      vi_combined_flag  vi_diff  vi_combined_z   dz
# 67           2.333333        2          0.428  0.0
# 117          2.333333        2          0.428  0.0
# 167          2.333333        2          0.428  0.0
#               TargetID  ExpID  Spec version  Redrock version Redrock spectype  \
# 785  35185712458371294     -1             0                0           GALAXY
# 835  35185712458371294     -1             0                0           GALAXY
#
#      Redrock z VI scanner  VI class VI issue    VI z VI spectype  \
# 785      0.248     acedge         4       --  0.2476      GALAXY
# 835      0.248       rita         2       --      --          --
#
#                                 VI comment  best redshift  vi_combined_flag  \
# 785                                    LRG         0.2476               3.0
# 835   continuum only"," no strong features         0.2480               3.0
#
#      vi_diff  vi_combined_z        dz
# 785        2         0.2478  0.000321
# 835        2         0.2478  0.000321
#               TargetID  ExpID  Spec version  Redrock version Redrock spectype  \
# 748  35185718485585807     -1             0                0           GALAXY
# 798  35185718485585807     -1             0                0           GALAXY
#
#      Redrock z VI scanner  VI class VI issue    VI z VI spectype  \
# 748      0.329     acedge         4       --  0.3287      GALAXY
# 798      0.329       rita         2       --      --          --
#
#                                    VI comment  best redshift  \
# 748                                       LRG         0.3287
# 798  break in the right place"," possible H&K         0.3290
#
#      vi_combined_flag  vi_diff  vi_combined_z        dz
# 748               3.0        2        0.32885  0.000226
# 798               3.0        2        0.32885  0.000226
#               TargetID  ExpID  Spec version  Redrock version Redrock spectype  \
# 751  35185718489779354     -1             0                0           GALAXY
# 801  35185718489779354     -1             0                0           GALAXY
#
#      Redrock z VI scanner  VI class VI issue    VI z VI spectype  \
# 751      0.276     acedge         4       --  0.2764      GALAXY
# 801      0.276       rita         2       --      --          --
#
#                VI comment  best redshift  vi_combined_flag  vi_diff  \
# 751  weak but clear lines         0.2764               3.0        2
# 801    no strong features         0.2760               3.0        2
#
#      vi_combined_z        dz
# 751         0.2762  0.000313
# 801         0.2762  0.000313
#               TargetID  ExpID  Spec version  Redrock version Redrock spectype  \
# 891  35185718489780521     -1             0                0           GALAXY
# 941  35185718489780521     -1             0                0           GALAXY
#
#      Redrock z VI scanner  VI class VI issue    VI z VI spectype  \
# 891      0.118     acedge         4       --  0.1182      GALAXY
# 941      0.118       rita         2       --      --          --
#
#                                   VI comment  best redshift  vi_combined_flag  \
# 891                    LRG with some Hdelta?         0.1182               3.0
# 941   weak features"," continuum about right         0.1180               3.0
#
#      vi_diff  vi_combined_z        dz
# 891        2         0.1181  0.000179
# 941        2         0.1181  0.000179
#               TargetID  ExpID  Spec version  Redrock version Redrock spectype  \
# 478  35185766816546922     -1             0                0           GALAXY
# 528  35185766816546922     -1             0                0           GALAXY
#
#      Redrock z VI scanner  VI class VI issue    VI z VI spectype VI comment  \
# 478      1.401        KAD         2        R  0.4643          --         --
# 528      1.401       rita         0       --      --          --         --
#
#      best redshift  vi_combined_flag  vi_diff  vi_combined_z        dz
# 478         0.4643               1.0        2        0.93265  0.484671
# 528         1.4010               1.0        2        0.93265  0.484671
#               TargetID  ExpID  Spec version  Redrock version Redrock spectype  \
# 462  35185766820745119     -1             0                0           GALAXY
# 512  35185766820745119     -1             0                0           GALAXY
#
#      Redrock z VI scanner  VI class VI issue    VI z VI spectype  \
# 462      0.536        KAD         4        R  0.1716          --
# 512      0.536       rita         2       --      --          --
#
#               VI comment  best redshift  vi_combined_flag  vi_diff  \
# 462                   --         0.1716               3.0        2
# 512   single secure line         0.5360               3.0        2
#
#      vi_combined_z        dz
# 462         0.3538  0.269168
# 512         0.3538  0.269168

# %% [markdown]
# ## This is where I resolve things manually - with care!!
# ### I think it's better to keep it in a notebook, as typos can be backtracked rather than a single manual edit of a text file
#
# Suggestion: we edit either 'dz' or 'vi diff' or 'vi_combined_flag' to resolve conflict. At the end, we look for conflicts again and we should find none.

# %%
#first, keep a safe copy of the original dataframe
vi_safe = vi_df.copy()

# %%
#for example, after inspecting the first problematic VI, I manually edit the fields that are yielding a conflict

#first, remind myself of the problem:
display(vi_df[vi_df.TargetID==unique_targets[0]])
# Out:
#               TargetID  ExpID  Spec version  Redrock version Redrock spectype  \
# 75   35185712449980146     -1             0                0           GALAXY
# 125  35185712449980146     -1             0                0           GALAXY
# 175  35185712449980146     -1             0                0           GALAXY
#
#      Redrock z VI scanner  VI class VI issue    VI z VI spectype  \
# 75        0.07        KAD         4       --      --          --
# 125       0.07     acedge         3       --  0.0704      GALAXY
# 175       0.07       rita         2       --      --          --
#
#                                      VI comment  best redshift  \
# 75                                           --         0.0700
# 125       weak lines but consistent with z=0.07         0.0704
# 175   blue jump; possible Ha; no other features         0.0700
#
#      vi_combined_flag  vi_diff  vi_combined_z        dz
# 75                3.0        2       0.070133  0.000374
# 125               3.0        2       0.070133  0.000374
# 175               3.0        2       0.070133  0.000374

# %%
#now I change either 'best redshift' or 'vi ' or 'vi_combined_flag' to resolve conflict
#in this case there are two conflicts: dz and vi_diff. I'm going to keep Alastair's VI redshift, and keep the combined flag, and remove the problematic vi_diff by setting VI class to VI combined
vi_df.loc[vi_df.TargetID==unique_targets[0], 'best redshift'] = 0.0704
vi_df.loc[vi_df.TargetID==unique_targets[0], 'VI class'] = 3.0


#look at the values again to make sure all is well
display(vi_df[vi_df.TargetID==unique_targets[0]])
# Out:
#               TargetID  ExpID  Spec version  Redrock version Redrock spectype  \
# 75   35185712449980146     -1             0                0           GALAXY
# 125  35185712449980146     -1             0                0           GALAXY
# 175  35185712449980146     -1             0                0           GALAXY
#
#      Redrock z VI scanner  VI class VI issue    VI z VI spectype  \
# 75        0.07        KAD       3.0       --      --          --
# 125       0.07     acedge       3.0       --  0.0704      GALAXY
# 175       0.07       rita       3.0       --      --          --
#
#                                      VI comment  best redshift  \
# 75                                           --         0.0704
# 125       weak lines but consistent with z=0.07         0.0704
# 175   blue jump; possible Ha; no other features         0.0704
#
#      vi_combined_flag  vi_diff  vi_combined_z        dz
# 75                3.0        2       0.070133  0.000374
# 125               3.0        2       0.070133  0.000374
# 175               3.0        2       0.070133  0.000374

# %%
#next one!
display(vi_df[vi_df.TargetID==unique_targets[1]])
# Out:
#               TargetID  ExpID  Spec version  Redrock version Redrock spectype  \
# 82   35185712454174940     -1             0                0              QSO
# 132  35185712454174940     -1             0                0              QSO
# 182  35185712454174940     -1             0                0              QSO
#
#      Redrock z VI scanner  VI class VI issue    VI z VI spectype  \
# 82       1.496        KAD       1.0       RS  0.1475          --
# 132      1.496     acedge       0.0        S      --          --
# 182      1.496       rita       1.0       --      --          --
#
#                                             VI comment  best redshift  \
# 82   Unusual spectrum"," no strong features (possib...         0.1475
# 132                                          no signal         1.4960
# 182                                       Mayne noise?         1.4960
#
#      vi_combined_flag  vi_diff  vi_combined_z       dz
# 82           0.666667        1         1.0465  0.65893
# 132          0.666667        1         1.0465  0.65893
# 182          0.666667        1         1.0465  0.65893

# %%
#now I change either 'best redshift' or 'vi ' or 'vi_combined_flag' to resolve conflict
#in this case I can't make a call without looking at the actual spectra, but let's assume I agree with Kelly! The only conflict is dz, so I only need to change 'best redshift'

vi_df.loc[vi_df.TargetID==unique_targets[1], 'best redshift'] = 0.1475

#look at the values again to make sure all is well
display(vi_df[vi_df.TargetID==unique_targets[1]])
# Out:
#               TargetID  ExpID  Spec version  Redrock version Redrock spectype  \
# 82   35185712454174940     -1             0                0              QSO
# 132  35185712454174940     -1             0                0              QSO
# 182  35185712454174940     -1             0                0              QSO
#
#      Redrock z VI scanner  VI class VI issue    VI z VI spectype  \
# 82       1.496        KAD       1.0       RS  0.1475          --
# 132      1.496     acedge       0.0        S      --          --
# 182      1.496       rita       1.0       --      --          --
#
#                                             VI comment  best redshift  \
# 82   Unusual spectrum"," no strong features (possib...         0.1475
# 132                                          no signal         0.1475
# 182                                       Mayne noise?         0.1475
#
#      vi_combined_flag  vi_diff  vi_combined_z       dz
# 82           0.666667        1         1.0465  0.65893
# 132          0.666667        1         1.0465  0.65893
# 182          0.666667        1         1.0465  0.65893

# %% [markdown]
# ### and so on...
#
# We should now recompute the conflicts, and not find any (except I didn't resolve everything! but the number of conflicts should now be 10, not 12)

# %%
vi_gp = vi_df.groupby(['TargetID'])
vi_insp = vi_gp.filter(lambda x: ( ( (x['VI class'].max()-x['VI class'].min()) >= 2) 
                       | ( (x['best redshift'].max() - x['best redshift'].min()) / (1+x['best redshift'].mean()) > 0.0033 ) )
                       & (len(x) >= 2)) #x is a group by TargetID

# %%
unique_targets = np.unique(vi_insp['TargetID'].tolist())
print('Targets with problematic VI: ', unique_targets)
print('Total number of conflicts to resolve: ', len(unique_targets))
# Out:
# Targets with problematic VI:  [35185712454175202 35185712454175731 35185712454176111 35185712454176649
#  35185712458371294 35185718485585807 35185718489779354 35185718489780521
#  35185766816546922 35185766820745119]
# Total number of conflicts to resolve:  10

# %%
#group by TargetID and make a csv file with the 1st of each group.
vi_gp.first().to_csv(VI_dir+'truth_table_test.txt')
